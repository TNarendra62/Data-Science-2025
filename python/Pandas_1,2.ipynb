# %%
# each column is Data Frame is Called "----SERIES----"
import pandas as pd

df = pd.DataFrame([[34,42,53,94],[65,83,23,78]], columns=['A','B','C','D'],index='X Y'.split())
print(df)
# Out:
#     A   B   C   D
# X  34  42  53  94
# Y  65  83  23  78

# %%
df.index  #gives all the row names
# Out:
# Index(['X', 'Y'], dtype='object')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.shape
# Out:
# (2, 4)

# %%
df.values
# Out:
# array([[34, 42, 53, 94],
#        [65, 83, 23, 78]])

# %%
# to Generate Random data
import numpy as np
df= pd.DataFrame(np.random.randint(0,100,(5,5)),columns='A B C D E'.split(),index="X Y Z P Q".split())
print(df)
# Out:
#     A   B   C   D   E
# X  83  64  43   7  39
# Y  67  60  72  13  49
# Z  36  94   5  60  12
# P   5  86  75  95  48
# Q  18  48  40  19  57

# %% [markdown]
# #Real Data set Working

# %%
df1= pd.read_excel('/content/drive/MyDrive/DataSet for pandas/Sample - Superstore.xls')

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df1.iloc[0:1,:]  #same as numpy just add ----dataset_name.iloc------
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %%
df1.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 0  FUR-BO-10001798  Furniture    Bookcases
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount    Profit
# 0       0.0   41.9136
# 1       0.0  219.5820
#
# [2 rows x 21 columns]

# %%
df1.tail(2)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID Customer Name   Segment        Country         City  ...  \
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16         2
#
#       Discount  Profit
# 9992       0.0  13.320
# 9993       0.0  72.948
#
# ...

# %%
#if i need specific columns
df1[['Customer ID','Country']]
# Out:
#      Customer ID        Country
# 0       CG-12520  United States
# 1       CG-12520  United States
# 2       DV-13045  United States
# 3       SO-20335  United States
# 4       SO-20335  United States
# ...          ...            ...
# 9989    TB-21400  United States
# 9990    DB-13060  United States
# 9991    DB-13060  United States
# 9992    DB-13060  United States
# 9993    CC-12220  United States
#
# [9994 rows x 2 columns]

# %% [markdown]
# # Append means (add below the table)
# # concat means (add to right side of table)
# # concat axis=0  append below
# # concat axis=1 append right

# %%
#for join a 2 tables use syntax as merge
#inner = pd.merge(table1,table2, on= '',how ='inner')

# %%
# to make any column as index name (row name)
# then df.set_index('column name',inplace=true)
# inplace=true this makes changes permanents

# %%
#df.reset_index()  makesback to original
# df.reset_index(inplace=true)

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# df1['Customer Name'].unique()  gives unique values in that column
df1['Customer Name'].nunique() # counts  unique values
# Out:
# 793

# %%
df1['City'].head(10).value_counts()  # counts no of value repeating in that selected column
# Out:
# City
# Los Angeles        6
# Henderson          2
# Fort Lauderdale    2
# Name: count, dtype: int64

# %%
df1['City'].head(10).value_counts(normalize=True)  # gives percentage
# Out:
# City
# Los Angeles        0.6
# Henderson          0.2
# Fort Lauderdale    0.2
# Name: proportion, dtype: float64

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df1.groupby('City')['Sales'].sum()  # if u want to analyse between one dimension and one measure use groupby
# Out:
# City
# Aberdeen         25.500
# Abilene           1.392
# Akron          2729.986
# Albuquerque    2220.160
# Alexandria     5519.570
#                  ...
# Woonsocket      195.550
# Yonkers        7657.666
# York            817.978
# Yucaipa          50.800
# Yuma            840.865
# Name: Sales, Length: 531, dtype: float64

# %%
df1.groupby('City')['Sales'].min()
# Out:
# City
# Aberdeen       25.500
# Abilene         1.392
# Akron           2.286
# Albuquerque     4.280
# Alexandria     12.420
#                 ...
# Woonsocket     45.360
# Yonkers        10.896
# York           37.896
# Yucaipa        50.800
# Yuma           10.496
# Name: Sales, Length: 531, dtype: float64

# %%
df1.groupby('City')['Sales'].describe().head()  # gives all min,max,std,mean and all
# Out:
#              count        mean          std     min      25%      50%  \
# City
# Aberdeen       1.0   25.500000          NaN  25.500  25.5000   25.500
# Abilene        1.0    1.392000          NaN   1.392   1.3920    1.392
# Akron         21.0  129.999333   168.318749   2.286  14.3520   25.560
# Albuquerque   14.0  158.582857   161.967111   4.280  36.3075  104.525
# Alexandria    16.0  344.973125  1025.875022  12.420  22.0800   27.025
#
#                   75%       max
# City
# Aberdeen      25.5000    25.500
# Abilene        1.3920     1.392
# Akron        247.1880   665.408
# Albuquerque  245.6250   595.000
# Alexandria   163.5075  4164.050

# %%
#calculate region wise sales
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df1.groupby(['Region','Category'])[['Sales','Profit']].count()
# Out:
#                          Sales  Profit
# Region  Category
# Central Furniture          481     481
#         Office Supplies   1422    1422
#         Technology         420     420
# East    Furniture          601     601
#         Office Supplies   1712    1712
#         Technology         535     535
# South   Furniture          332     332
#         Office Supplies    995     995
#         Technology         293     293
# West    Furniture          707     707
#         Office Supplies   1897    1897
#         Technology         599     599

# %%
# want to analyse between 2 dimensions column then use crosstab
pd.crosstab(df1['Region'],df1['Category'])
# Out:
# Category  Furniture  Office Supplies  Technology
# Region
# Central         481             1422         420
# East            601             1712         535
# South           332              995         293
# West            707             1897         599

# %%
df1['Category'].head()
# Out:
# 0          Furniture
# 1          Furniture
# 2    Office Supplies
# 3          Furniture
# 4    Office Supplies
# Name: Category, dtype: object

# %%
pd.get_dummies(df1['Category']).head()
# Out:
#    Furniture  Office Supplies  Technology
# 0       True            False       False
# 1       True            False       False
# 2      False             True       False
# 3       True            False       False
# 4      False             True       False

# %%
pd.cut(df1['Sales'], bins=[0,50,500,1000],labels=['low','Med','High']).head()  #cut is used like range if 0 to 50 then low like that
# Out:
# 0     Med
# 1    High
# 2     low
# 3    High
# 4     low
# Name: Sales, dtype: category
# Categories (3, object): ['low' < 'Med' < 'High']

# %%
df1['Sales'].head()
# Out:
# 0    261.9600
# 1    731.9400
# 2     14.6200
# 3    957.5775
# 4     22.3680
# Name: Sales, dtype: float64
